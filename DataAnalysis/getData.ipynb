# %% [markdown]
# # Get data from api

# %%
! python -m pip install requests
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\appdata\local\programs\python\python310\lib\site-packages)

# %%
import requests

url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4MGI4MTg5ZmYzZWQzNjljMDZhNzE0NTdiNGJlMmU5ZCIsIm5iZiI6MTc0MzA3NDM0NS4xMDMwMDAyLCJzdWIiOiI2N2U1MzQyOTMzYTc0MzQxZTMxMDlmNzUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.MjLf9ZxV-09-rN9_9InskU5W2VCpBss7b5DR6dvUnwY"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/gsQJOfeW45KLiQeEIsom94QPQwb.jpg","genre_ids":[28,53],"id":1125899,"original_language":"en","original_title":"Cleaner","overview":"When a group of radical activists take over an energy company's annual gala, seizing 300 hostages, an ex-soldier turned window cleaner suspended 50 storeys up on the outside of the building must save those trapped inside, including her younger brother.","popularity":459.5805,"poster_path":"/mwzDApMZAGeYCEVjhegKvCzDX0W.jpg","release_date":"2025-02-19","title":"Cleaner","video":false,"vote_average":6.3,"vote_count":71},{"adult":false,"backdrop_path":"/m2mzlsJjE3UAqeUB5fLUkpWg4Iq.jpg","genre_ids":[53,878],"id":1165067,"original_language":"en","original_title":"Cosmic Chaos","overview":"Battles in virtual reality, survival in a post-apocalyptic wasteland, a Soviet spaceship giving a distress signal - Fantastic stories created with advanced special effects and passion.","popularity":503.4688,"poster_path":"/
# ...

# %%
requests.get(url,headers=headers)
# Out:
# <Response [200]>

# %%
requests.get(url,headers=headers).json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/gsQJOfeW45KLiQeEIsom94QPQwb.jpg',
#    'genre_ids': [28, 53],
#    'id': 1125899,
#    'original_language': 'en',
#    'original_title': 'Cleaner',
#    'overview': "When a group of radical activists take over an energy company's annual gala, seizing 300 hostages, an ex-soldier turned window cleaner suspended 50 storeys up on the outside of the building must save those trapped inside, including her younger brother.",
#    'popularity': 459.5805,
#    'poster_path': '/mwzDApMZAGeYCEVjhegKvCzDX0W.jpg',
#    'release_date': '2025-02-19',
#    'title': 'Cleaner',
#    'video': False,
#    'vote_average': 6.3,
#    'vote_count': 71},
#   {'adult': False,
#    'backdrop_path': '/m2mzlsJjE3UAqeUB5fLUkpWg4Iq.jpg',
#    'genre_ids': [53, 878],
#    'id': 1165067,
#    'original_language': 'en',
#    'original_title': 'Cosmic Chaos',
# ...

# %%
requests.get(url,headers=headers).text
# Out:
# '{"page":1,"results":[{"adult":false,"backdrop_path":"/gsQJOfeW45KLiQeEIsom94QPQwb.jpg","genre_ids":[28,53],"id":1125899,"original_language":"en","original_title":"Cleaner","overview":"When a group of radical activists take over an energy company\'s annual gala, seizing 300 hostages, an ex-soldier turned window cleaner suspended 50 storeys up on the outside of the building must save those trapped inside, including her younger brother.","popularity":459.5805,"poster_path":"/mwzDApMZAGeYCEVjhegKvCzDX0W.jpg","release_date":"2025-02-19","title":"Cleaner","video":false,"vote_average":6.3,"vote_count":71},{"adult":false,"backdrop_path":"/m2mzlsJjE3UAqeUB5fLUkpWg4Iq.jpg","genre_ids":[53,878],"id":1165067,"original_language":"en","original_title":"Cosmic Chaos","overview":"Battles in virtual reality, survival in a post-apocalyptic wasteland, a Soviet spaceship giving a distress signal - Fantastic stories created with advanced special effects and passion.","popularity":503.4688,"poster_path":
# ...

# %%
response=requests.get(url,headers=headers).json()

# %%
response
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/gsQJOfeW45KLiQeEIsom94QPQwb.jpg',
#    'genre_ids': [28, 53],
#    'id': 1125899,
#    'original_language': 'en',
#    'original_title': 'Cleaner',
#    'overview': "When a group of radical activists take over an energy company's annual gala, seizing 300 hostages, an ex-soldier turned window cleaner suspended 50 storeys up on the outside of the building must save those trapped inside, including her younger brother.",
#    'popularity': 459.5805,
#    'poster_path': '/mwzDApMZAGeYCEVjhegKvCzDX0W.jpg',
#    'release_date': '2025-02-19',
#    'title': 'Cleaner',
#    'video': False,
#    'vote_average': 6.3,
#    'vote_count': 71},
#   {'adult': False,
#    'backdrop_path': '/m2mzlsJjE3UAqeUB5fLUkpWg4Iq.jpg',
#    'genre_ids': [53, 878],
#    'id': 1165067,
#    'original_language': 'en',
#    'original_title': 'Cosmic Chaos',
# ...

# %%
for i in response['results']:
    print(i['title'], i['vote_average'])
# Out:
# Cleaner 6.3
# Cosmic Chaos 3.3
# Captain America: Brave New World 6.125
# The Codes of War 8.6
# Snow White 4.5
# Z Zone 7.6
# Batman Ninja vs. Yakuza League 6.645
# Mufasa: The Lion King 7.5
# Moana 2 7.1
# Popeye the Slayer Man 6.7
# Counterattack 8.48
# The Electric State 6.589
# Old Guy 5.5
# The Gorge 7.7
# Flight Risk 6.1
# Hellhound 6.48
# The Monkey 5.9
# Demon City 6.9
# Sonic the Hedgehog 3 7.8
# Sky Force 7.7

# %%
import pandas as pd

# %%
d ={'name':['rahul','rohit'],'Age':[12,45]}

# %%
df = pd.DataFrame(d)
df
# Out:
#     name  Age
# 0  rahul   12
# 1  rohit   45

# %%
popularity = []
vote_count = []
original_language = []
title = []
vote_average = []
overview = []
release_data = []

# %%
for i in response['results']:
    popularity.append(i['popularity'])
    vote_count.append(i['vote_count'])
    original_language.append(i['original_language'])
    title.append(i['title'])
    vote_average.append(i['overview'])
    overview.append(i['overview'])
    release_data.append(i['release_date'])

d = {'title':title, "overview":overview, "release_data":release_data, 'popularity':popularity, 'vote_count':vote_count,'original_language':original_language,'vote_average':vote_average,}

# %% [markdown]
# # If the  data length is not same then trim the data

# %%
min_len = min(len(v) for v in d.values())
d_trimmed = {k: v[:min_len] for k, v in d.items()}
df = pd.DataFrame(d_trimmed)
df
# Out:
#                                title  \
# 0                            Cleaner
# 1                            Cleaner
# 2                       Cosmic Chaos
# 3   Captain America: Brave New World
# 4                   The Codes of War
# 5                         Snow White
# 6                             Z Zone
# 7     Batman Ninja vs. Yakuza League
# 8              Mufasa: The Lion King
# 9                            Moana 2
# 10             Popeye the Slayer Man
# 11                     Counterattack
# 12                The Electric State
# 13                           Old Guy
# 14                         The Gorge
# 15                       Flight Risk
# 16                         Hellhound
# 17                        The Monkey
# 18                        Demon City
# 19              Sonic the Hedgehog 3
# 20                         Sky Force
# 21                           Cleaner
# 22                      Cosmic Chaos
# 23  Captain America: Brave New World
# ...

# %%
final = pd.DataFrame()
for j in range(1,501):  

    url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page={j}"

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4MGI4MTg5ZmYzZWQzNjljMDZhNzE0NTdiNGJlMmU5ZCIsIm5iZiI6MTc0MzA3NDM0NS4xMDMwMDAyLCJzdWIiOiI2N2U1MzQyOTMzYTc0MzQxZTMxMDlmNzUiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.MjLf9ZxV-09-rN9_9InskU5W2VCpBss7b5DR6dvUnwY"
    }

    response = requests.get(url, headers=headers)


    popularity = []
    vote_count = []
    original_language = []
    title = []
    vote_average = []
    overview = []
    release_data = []


    for i in response['results']:
        popularity.append(i['popularity'])
        vote_count.append(i['vote_count'])
        original_language.append(i['original_language'])
        title.append(i['title'])
        vote_average.append(i['overview'])
        overview.append(i['overview'])
        release_data.append(i['release_date'])

    d = {'title':title, "overview":overview, "release_data":release_data, 'popularity':popularity, 'vote_count':vote_count,'original_language':original_language,'vote_average':vote_average,}

    min_len = min(len(v) for v in d.values())
    d_trimmed = {k: v[:min_len] for k, v in d.items()}
    df = pd.DataFrame(d_trimmed)

    final = final.append(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 23
#      19 overview = []
#      20 release_data = []
# ---> 23 for i in response['results']:
#      24     popularity.append(i['popularity'])
#      25     vote_count.append(i['vote_count'])
#
# TypeError: 'Response' object is not subscriptable
