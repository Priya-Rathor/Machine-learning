# %% [markdown]
# # Type  of Data
#
# * Numerical Data
# * Categorical Data

# %%
# import the library
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2D Line plot

# %% [markdown]
# * Bivariate Analysis
# * Categorical -> numerical and numerical -> numerical
# * Use case - Time series data

# %%
# plotting a simple function
price = [48000,54000,57000,47000,30000,20000]
year = [2015,2016,2017,2018,2019,2020]

plt.plot(price, year)

# %%
# from a pandas dataframe
batsman = pd.read_csv('sharma-kohli.csv')
batsman
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
Virat = pd.read_csv('runs.csv')
Rohit = pd.read_csv('rohit.csv')
Sachin = pd.read_csv('Sachin.csv')

# %%
plt.plot(Virat['Year'],Virat['Runs'],label ='Virat')
plt.plot(Rohit['Year'],Rohit['Runs'], label='Rohit')
plt.plot(Sachin['Year'],Sachin['Runs'], label = 'Sachin')
plt.legend()

# %%
plt.plot(batsman['index'],batsman['V Kohli'])

# %%
#  plotting multuple plots
plt.plot(batsman['index'],batsman['V Kohli'])
plt.plot(batsman['index'],batsman['RG Sharma'])

# %%
# labels title 
plt.plot(batsman['index'],batsman['V Kohli'])
plt.plot(batsman['index'],batsman['RG Sharma'])

plt.title('Rohit Sharma Vs Virat kohli career Comparion')
plt.xlabel('Season')
plt.ylabel('Runs scored')
# Out:
# Text(0, 0.5, 'Runs score')

# %%
# colors(hex) and line(width and style) and marker(size)
plt.plot(batsman['index'],batsman['V Kohli'],color='green')
plt.plot(batsman['index'],batsman['RG Sharma'],color='black')

plt.title('Rohit Shama Vs Virat Kohli Career Comparison')
plt.xlabel('Season')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
# style
plt.plot(batsman['index'],batsman['V Kohli'],color='green',linestyle='dashed')
plt.plot(batsman['index'],batsman['RG Sharma'],color='black',linestyle='dashed')

plt.title('Rohit Shama Vs Virat Kohli Career Comparison')
plt.xlabel('Season')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
plt.plot(batsman['index'],batsman['V Kohli'],color='green',linestyle='dotted')
plt.plot(batsman['index'],batsman['RG Sharma'],color='black',linestyle='dashdot')

plt.title('Rohit Shama Vs Virat Kohli Career Comparison')
plt.xlabel('Season')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
plt.plot(batsman['index'],batsman['V Kohli'],color='green',linestyle='solid',linewidth=3)
plt.plot(batsman['index'],batsman['RG Sharma'],color='black',linestyle='dashed')

plt.title('Rohit Shama Vs Virat Kohli Career Comparison')
plt.xlabel('Season')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
plt.plot(batsman['index'],batsman['V Kohli'],color='green',linestyle='dashed',linewidth=3,marker='D')
plt.plot(batsman['index'],batsman['RG Sharma'],color='black',linestyle='dashed',marker='+')

plt.title('Rohit Shama Vs Virat Kohli Career Comparison')
plt.xlabel('Season')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
plt.plot(batsman['index'],batsman['V Kohli'],color='green',linestyle='dashed',linewidth=3,marker='D',markersize=10)
plt.plot(batsman['index'],batsman['RG Sharma'],color='black',linestyle='dashed',marker='+')

plt.title('Rohit Shama Vs Virat Kohli Career Comparison')
plt.xlabel('Season')
plt.ylabel('Runs Scored')
# Out:
# Text(0, 0.5, 'Runs Scored')

# %%
# legend -> loacation
plt.plot(batsman['index'],batsman['V Kohli'],color='green',linestyle='dashed',linewidth=3,marker='D',label='Virat')
plt.plot(batsman['index'],batsman['RG Sharma'],color='black',linestyle='dashed',marker='+',label = 'Rohit')

plt.title('Rohit Shama Vs Virat Kohli Career Comparison')
plt.xlabel('Season')
plt.ylabel('Runs Scored')

plt.legend()

# %%
plt.plot(batsman['index'],batsman['V Kohli'],color='green',linestyle='dashed',linewidth=3,marker='D',label='Virat')
plt.plot(batsman['index'],batsman['RG Sharma'],color='black',linestyle='dashed',marker='+',label = 'Rohit')

plt.title('Rohit Shama Vs Virat Kohli Career Comparison')
plt.xlabel('Season')
plt.ylabel('Runs Scored')

plt.legend(loc='right')

# %%
# limiting axes
price = [48000,54000,57000,47000,30000,4300000]
year = [2015,2016,2017,2018,2019,2020]

plt.plot(year,price)

# %%
price = [48000,54000,57000,47000,30000,4300000]
year = [2015,2016,2017,2018,2019,2020]

plt.plot(year,price)
plt.ylim(0,100000)
# Out:
# (0.0, 100000.0)

# %%
price = [48000,54000,57000,47000,30000,4300000]
year = [2015,2016,2017,2018,2019,2020]

plt.plot(year,price)
plt.ylim(0,100000)
plt.xlim(2017,2019)
# Out:
# (2017.0, 2019.0)

# %%
# grid

plt.plot(batsman['index'],batsman['V Kohli'],color='green',linestyle='dashed',linewidth=3,marker='D',label='Virat')
plt.plot(batsman['index'],batsman['RG Sharma'],color='black',linestyle='dashed',marker='+',label = 'Rohit')

plt.title('Rohit Shama Vs Virat Kohli Career Comparison')
plt.xlabel('Season')
plt.ylabel('Runs Scored')

plt.legend(loc='right')
plt.grid()

# %% [markdown]
# # show function :- this is the function which  is use to show the graph this is console that why  it is showing this but in other editter we have to write plt.show()  function .

# %%
# show 
plt.plot(batsman['index'],batsman['V Kohli'],color='green',linestyle='dashed',linewidth=3,marker='D',label='Virat')
plt.plot(batsman['index'],batsman['RG Sharma'],color='black',linestyle='dashed',marker='+',label = 'Rohit')

plt.title('Rohit Shama Vs Virat Kohli Career Comparison')
plt.xlabel('Season')
plt.ylabel('Runs Scored')

plt.show()

# %% [markdown]
# # Scatter Plots

# %% [markdown]
# * Bivariate Analysis
# * numerical vs numerical
# * Use case - Finding correlation

# %%
# plt.scatter simple function 
x = np.linspace(-10,10,50)

y = 10*x + 3 + np.random.randint(0,300,50)
y
# Out:
# array([127.        , -38.91836735, 198.16326531, 204.24489796,
#        179.32653061, 108.40816327, 201.48979592,  16.57142857,
#         -7.34693878,  88.73469388, 109.81632653, 245.89795918,
#        182.97959184, 141.06122449, -10.85714286,   8.2244898 ,
#         -0.69387755, -10.6122449 , 112.46938776, 279.55102041,
#        246.63265306,  11.71428571, 195.79591837, 260.87755102,
#        238.95918367, 210.04081633, 272.12244898, 223.20408163,
#         39.28571429, 214.36734694, 194.44897959, 128.53061224,
#        199.6122449 ,  89.69387755, 237.7755102 ,  93.85714286,
#        149.93877551, 168.02040816,  81.10204082, 277.18367347,
#         95.26530612, 114.34693878, 183.42857143, 251.51020408,
#        355.59183673, 201.67346939, 283.75510204, 272.83673469,
#        388.91836735, 170.        ])

# %%
plt.scatter(x,y)

# %%
# plt.scatter on pandas data
df = pd.read_csv('batter.csv')
df = df.head(50)
df
# Out:
#             batter  runs        avg  strike_rate
# 0          V Kohli  6634  36.251366   125.977972
# 1         S Dhawan  6244  34.882682   122.840842
# 2        DA Warner  5883  41.429577   136.401577
# 3        RG Sharma  5881  30.314433   126.964594
# 4         SK Raina  5536  32.374269   132.535312
# 5   AB de Villiers  5181  39.853846   148.580442
# 6         CH Gayle  4997  39.658730   142.121729
# 7         MS Dhoni  4978  39.196850   130.931089
# 8       RV Uthappa  4954  27.522222   126.152279
# 9       KD Karthik  4377  26.852761   129.267572
# 10       G Gambhir  4217  31.007353   119.665153
# 11       AT Rayudu  4190  28.896552   124.148148
# 12       AM Rahane  4074  30.863636   117.575758
# 13        KL Rahul  3895  46.927711   132.799182
# 14       SR Watson  3880  30.793651   134.163209
# 15       MK Pandey  3657  29.731707   117.739858
# 16       SV Samson  3526  29.140496   132.407060
# 17      KA Pollard  3437  28.404959   140.457703
# 18    F du Plessis  3403  34.373737   127.167414
# 19       YK Pathan  3222  29.290909   138.046272
# 20     BB McCullum  2882  27.711538   126.848592
# 21         RR Pant  2851  34.768293   142.550000
# 22        PA Patel  2848  22.603175   116.625717
# 23      JC Buttler  2832  39.333333   144.859335
# 24         SS Iyer  2780  31.235955   121.132898
# 25       Q de Kock  2767  31.804598   130.951254
# 26    Yuvraj Singh  2754  24.810811   124.784776
# 27        V Sehwag  2728  27.555556   148.827059
# 28        SA Yadav  2644  29.707865   134.009123
# 29         M Vijay  2619  25.930693   118.614130
# 30       RA Jadeja  2502  26.617021   122.108346
# 31       SPD Smith  2495  34.652778   124.812406
# 32        SE Marsh  2489  39.507937   130.109775
# 33       DA Miller  2455  36.102941   133.569097
# 34       JH Kallis  2427  28.552941   105.936272
# 35         WP Saha  2427  25.281250   124.397745
# 36        DR Smith  2385  28.392857   132.279534
# 37      MA Agarwal  2335  22.669903   129.506378
# 38    SR Tendulkar  2334  33.826087   114.187867
# 39      GJ Maxwell  2320  25.494505   147.676639
# 40          N Rana  2181  27.961538   130.053667
# 41        R Dravid  2174  28.233766   113.347237
# 42   KS Williamson  2105  36.293103   123.315759
# 43        AJ Finch  2092  24.904762   123.349057
# 44    AC Gilchrist  2069  27.223684   133.054662
# 45      AD Russell  2039  29.985294   168.234323
# 46       JP Duminy  2029  39.784314   120.773810
# 47      MEK Hussey  1977  38.764706   119.963592
# 48       HH Pandya  1972  29.878788   140.256046
# 49    Shubman Gill  1900  32.203390   122.186495

# %%
plt.scatter(df['avg'],df['strike_rate'],marker='+')
plt.title('Avg and SR analysis of Top 50 Batsman')
plt.xlabel("average")
plt.ylabel('SR')
# Out:
# Text(0, 0.5, 'SR')

# %%
# size 
tips = sns.load_dataset('tips')
plt.scatter(tips['total_bill'],tips['tip'],s=tips['size']*20)

# %%
# scatterplot using plt.plot
plt.plot(tips['total_bill'],tips['tip'],'o')

# %% [markdown]
# # Bar Chart

# %% [markdown]
# * Bivariate Analysis
# * Numerical vs Categorical
# * Use case - Aggreate analysis of group

# %%
# simple bar chart
childern =[10,20,40,10,30]
colors = ['red','blue','green','yellow','pink']

plt.bar(colors,childern)
# Out:
# <BarContainer object of 5 artists>

# %%
# bar chart using data

# %%
# horizontal bar chart
plt.barh(colors,childern,color='black')
# Out:
# <BarContainer object of 5 artists>

# %%
# multiple Bar charts
df = pd.read_csv('batsman_season_record.csv')
df
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(df['batsman'],df['2015'],width=0.5)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(np.arange(df.shape[0])-0.2,df['2015'],width=0.2)
plt.bar(np.arange(df.shape[0]),df['2016'],width=0.2)
plt.bar(np.arange(df.shape[0])+0.2,df['2017'],width=0.2)

plt.xticks(np.arange(df.shape[0]), df['batsman'])
plt.show()
