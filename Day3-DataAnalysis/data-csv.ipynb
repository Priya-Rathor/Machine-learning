# %% [markdown]
# # full  form of csv :- commama seprated value

# %%
import pandas as pd

# %% [markdown]
# # Opening a local  csv file

# %%
df = pd.read_csv('crypto_market_data.csv')
df
# Out:
#                             id  symbol                              name  \
# 0                      bitcoin     btc                           Bitcoin
# 1                     ethereum     eth                          Ethereum
# 2                       tether    usdt                            Tether
# 3                       ripple     xrp                               XRP
# 4                  binancecoin     bnb                               BNB
# ..                         ...     ...                               ...
# 395                   biconomy    bico                          Biconomy
# 396              qubic-network   qubic                             Qubic
# 397        elixir-staked-deusd  sdeusd               Elixir Staked deUSD
# 398  usd-coin-ethereum-bridged  usdc.e  Arbitrum Bridged USDC (Arbitrum)
# 399                  prometeus    prom                              Prom
#
#                                                  image  current_price  \
# ...

# %% [markdown]
# # Opening a csv file from an URL

# %%
import requests
from io import StringIO

url = "https://github.com/tokern/piicatcher/blob/master/tests/samples/sample-data.csv"
headers = {"User-Agent":"Mozilla/5.0 (Macintosh; intel Mac OS X 10.14; rv:66.0) Gecko/20100101 firefox/66.0"}

req = requests.get(url,headers=headers)

data = StringIO(req.text)

pd.read_csv(data)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[5], line 11
#       7 req = requests.get(url,headers=headers)
#       9 data = StringIO(req.text)
# ---> 11 pd.read_csv(data)
#
# ...

# %%
import pandas as pd
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/tokern/piicatcher/master/tests/samples/sample-data.csv"
headers = {"User-Agent":"Mozilla/5.0"}

req = requests.get(url, headers=headers)

data = StringIO(req.text)

df = pd.read_csv(data)

print(df.head())  # just to confirm it's working
# Out:
#             id gender   birthdate maiden_name   lname     fname  \
# 0  172-32-1176      m  1958/04/21       Smith   White   Johnson
# 1  514-14-8905      f  1944/12/22      Amaker  Borden    Ashley
# 2  213-46-8915      f  1958/04/21      Pinson   Green  Marjorie
# 3  524-02-7657      m  1962/03/25        Hall  Munsch    Jerome
# 4  489-36-8350      m  1964/09/06      Porter  Aragon    Robert
#
#                 address         city state    zip         phone  \
# 0        10932 Bigge Rd   Menlo Park    CA  94025  408 496-7223
# 1   4469 Sherman Street         Goff    KS  66428  785-939-6046
# 2     309 63rd St. #411      Oakland    CA  94618  415 986-7020
# 3        2183 Roy Alley   Centennial    CO  80112  303-901-6123
# 4  3181 White Oak Drive  Kansas City    MO  66215  816-645-6936
#
#                 email cc_type            cc_number  cc_cvc cc_expiredate
# 0   jwhite@domain.com       m  5270 4267 6450 5516     123    2010/06/25
# ...

# %% [markdown]
# # sep Parameter

# %%
pd.read_csv('xyz.tsv',sep='\t',names =['sno','name','release_year','rating','genres'])

# %% [markdown]
# # index_col parameter

# %%
# replace index of that defult to  that coluom which is present in data
pd.read_csv('crypto_market_data.csv', index_col='market_cap_rank')
# Out:
#                                         id  symbol  \
# market_cap_rank
# 1                                  bitcoin     btc
# 2                                 ethereum     eth
# 3                                   tether    usdt
# 4                                   ripple     xrp
# 5                              binancecoin     bnb
# ...                                    ...     ...
# 396                               biconomy    bico
# 397                          qubic-network   qubic
# 398                    elixir-staked-deusd  sdeusd
# 399              usd-coin-ethereum-bridged  usdc.e
# 400                              prometeus    prom
#
#                                              name  \
# market_cap_rank
# 1                                         Bitcoin
# 2                                        Ethereum
# 3                                          Tether
# 4                                             XRP
# 5                                             BNB
# ...

# %% [markdown]
# # Header parameter

# %%
pd.read_csv('crypto_market_data.csv', header=1)
# Out:
#                        bitcoin     btc                           Bitcoin  \
# 0                     ethereum     eth                          Ethereum
# 1                       tether    usdt                            Tether
# 2                       ripple     xrp                               XRP
# 3                  binancecoin     bnb                               BNB
# 4                       solana     sol                            Solana
# ..                         ...     ...                               ...
# 394                   biconomy    bico                          Biconomy
# 395              qubic-network   qubic                             Qubic
# 396        elixir-staked-deusd  sdeusd               Elixir Staked deUSD
# 397  usd-coin-ethereum-bridged  usdc.e  Arbitrum Bridged USDC (Arbitrum)
# 398                  prometeus    prom                              Prom
#
#     https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400  \
# ...

# %% [markdown]
# # use_cols Parameter

# %%
# want accoding to your peramiters 
pd.read_csv('crypto_market_data.csv', usecols=['bitcoin'])

# %% [markdown]
# # squeeze parameters

# %%
# it is pandas seris object which take single peramiters
pd.read_csv('crypto_market_data.csv', usecols=['bitcoin'],squeeze =True)

# %% [markdown]
# # Skiprows/nrows Parameter

# %%
# use to check the  unwanted rows 
pd.read_csv('crypto_market_data.csv',skiprows=['row name'])
pd.read_csv('crypto_market_data.csv', nrows=100)

# %% [markdown]
# # Encoding parameter

# %%
pd.read_csv('crypto_market_data.csv',encoding='latin-1')

# %% [markdown]
# # skip bad lines

# %%
pd.read_csv('crypto_market_data.csv', sep=';',encoding='latin-1',error_bad_lines = False)

# %% [markdown]
# # dtypes parameter

# %%
# convert data types by using dtype={'colume_name':datatype}

# %% [markdown]
# # handling dates
# data comes in  a string so we are convert it into that data can we read
#
# * pd.read_csv('crypto_market_data.csv', parse_dates = ['date'])
#
#
# use info() to check  the date type
#
# * pd.read_csv('crypto_market_data.csv', parse_dates = ['date']).info()

# %% [markdown]
# # Convertors

# %%
def rename(name):
    if name == "Royal Challengers Bangalore":
        return "RCB"
    else:
        return name

# %%
pd.read_csv('crypto_market_data.csv', converters={'team1':rename})

# %% [markdown]
# # Na_values parameter

# %%
# which types of values you  want to consider as an NA values
pd.read_csv('crypto_market_data.csv', na_values=['male'])

# %% [markdown]
# # Loading a huge dataset in chunks

# %%
dfs = pd.read_csv('crypto_market_data.csv', chunksize=5000)

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (400, 26)
