# %%
import numpy as np
import pandas as pd

# %%
a = pd.Series([1,1,1,2,2,3])
a.value_counts()
# Out:
# 1    3
# 2    2
# 3    1
# Name: count, dtype: int64

# %%
# value_count(series and dataframe)
marks = pd.DataFrame([
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,70,14]
],columns=['qi','marks','package'])

marks
# Out:
#     qi  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     70       14

# %%
marks.value_counts()
# Out:
# qi   marks  package
# 80   70     14         1
# 90   70     7          1
# 100  80     10         1
# 120  100    14         1
# Name: count, dtype: int64
